# %% [markdown]
# # Byte-Pair encoding

# %% [markdown]
# **byte-pair encoding algorithm** is a simple data compression technique that iteratively replaces the most frequent pair of bytes in a sequence with a single, unused byte. It is often used as a sub-step in more complex algorithms, such as in **sentencepiece**.

# %% [markdown]
# first, the corpus needs to be made. This is done using iteratively applying a process_file function to each file name in a list of file names.

# %%
import re
import yaml
from pathlib import Path
import glob
from nltk.tokenize import RegexpTokenizer

corpus_dir = Path('data') 
document_paths = glob.glob(str(corpus_dir / '*.txt')) 

def process_document(file_path):
    with open(file_path, 'r') as f:
        data = f.read()
        
    yaml_header = re.search(r'---\n(.*?)\n---', data, re.DOTALL)
    metadata = yaml.safe_load(yaml_header.group(1))  # Parse YAML into a dictionary

    # Remove YAML frontmatter from the text
    text_without_yaml = re.sub(r'---\n(.*?)\n---', '', data, flags=re.DOTALL)

    tokens = RegexpTokenizer(r'\w+').tokenize(text_without_yaml)
    tokens = [t.lower() for t in tokens]
    
    document = dict(metadata=metadata, text=text_without_yaml, ws_tokens=tokens)
    
    return document

corpus = dict()

for path in document_paths:
    document = process_document(path)
    corpus[document['metadata']['title']] = document

# %%
for document in corpus:
    for key in corpus[document]['metadata']:
        print(f"{key} : {corpus[document]['metadata'][key]}")
        
    print(f"first 100 out of {len(corpus[document]['text'])} characters: {corpus[document]['text'][:100]}")
    print(f"first 30 out of {len(corpus[document]['ws_tokens'])} ws_tokens: {corpus[document]['ws_tokens'][:30]}")
    print()
# Out:
# title : Archeological Dig at Old Montreal Hospital on Hold by McGill University
# author : Emelia Fournier
# publisher : aptn news
# URL : https://www.aptnnews.ca/national-news/archeological-dig-old-montreal-hospital-on-hold-mcgill-university/
# summary : This article reports on the temporary halt of an archeological dig at an old Montreal hospital by McGill University.
# tags : ['news', 'indigenous']
# first 100 out of 5136 characters:
# A spokesperson for the Mohawk Mothers, or Kahnistensera, says the group feels pushed aside in the s
# first 30 out of 877 ws_tokens: ['a', 'spokesperson', 'for', 'the', 'mohawk', 'mothers', 'or', 'kahnistensera', 'says', 'the', 'group', 'feels', 'pushed', 'aside', 'in', 'the', 'search', 'for', 'unmarked', 'graves', 'on', 'a', 'site', 'owned', 'by', 'société', 'québécoise', 'des', 'infrastructures', 'or']
#
# title : mcgill-reports-nine-potential-grave-zones-at-new-vic-site-a-week-after-security-verbally-assaulted-mohawk-mothers
# author : jasjot grewal
# publisher : the tribune
# URL : https://www.thetribune.ca/news/mcgill-reports-nine-potential-grave-zones-at-new-vic-site-a-week-after-security-verbally-assaulted-mohawk-mothers-04092023/
# summary : summary
# tags : ['news', 'student']
# first 100 out of 8677 characters:
# On July 25, the Kanien’kehá:ka Kahnistensera (Mohawk Mothers) were verbally assaulted by security p
# first 30 out of 1434 ws_tokens: ['on', 'july', '25', 'the', 'kanien', 'kehá', 'ka', 'kahnistensera', 'mohawk', 'mothers', 'were', 'verbally', 'assaulted', 'by', 'security', 'personnel', 'on', 'mcgill', 's', 'new', 'vic', 'project', 'site', 'a', 'week', 'later', 'on', 'aug', '3', 'mcgill']
#
# title : Concern About Recent Actions
# author : Christopher Manfredi
# publisher : McGill University
# URL : concern_about_recent_actions.txt
# summary : This is an email from McGill University's Provost and Vice-Principal (Academic), Christopher Manfredi, addressing recent actions and concerns.
# tags : ['mcgill']
# first 100 out of 2400 characters:
# Following up on the last update I provided about the work being conducted on the former Royal Victo
# first 30 out of 377 ws_tokens: ['following', 'up', 'on', 'the', 'last', 'update', 'i', 'provided', 'about', 'the', 'work', 'being', 'conducted', 'on', 'the', 'former', 'royal', 'victoria', 'hospital', 'site', 'ground', 'penetrating', 'radar', 'work', 'was', 'performed', 'in', 'priority', 'areas', 'of']
#
# title : Mohawk Mothers Win Injunction Against McGill at David and Goliath Hearing
# author : emelia fournier
# publisher : aptn news
# URL : https://www.aptnnews.ca/national-news/mohawk-mothers-win-injunction-against-mcgill-at-david-and-goliath-hearing/
# summary : This article reports on the victory of Mohawk mothers who won an injunction against McGill University in a significant legal hearing.
# tags : ['news', 'indigenous']
# first 100 out of 6017 characters:
# The Mohawk Mothers, or Kanien’kehà:ka Kanistansera, obtained a temporary injunction against McGill
# first 30 out of 983 ws_tokens: ['the', 'mohawk', 'mothers', 'or', 'kanien', 'kehà', 'ka', 'kanistansera', 'obtained', 'a', 'temporary', 'injunction', 'against', 'mcgill', 'university', 'to', 'stop', 'the', 'renovation', 'and', 'excavation', 'of', 'a', 'hospital', 'where', 'group', 'says', 'unmarked', 'graves', 'are']
#
# title : its-empty-montreal-mohawk-womens-group-slams-popes-apology
# author : frédéric tomesco
# publisher : montreal gazette
# URL : https://montrealgazette.com/news/quebec/its-empty-montreal-mohawk-womens-group-slams-popes-apology
# summary : None
# tags : ['news']
# first 100 out of 1804 characters:
# Pope Francis’s landmark apology over residential schools drew sharp criticism from Indigenous spoke
# first 30 out of 300 ws_tokens: ['pope', 'francis', 's', 'landmark', 'apology', 'over', 'residential', 'schools', 'drew', 'sharp', 'criticism', 'from', 'indigenous', 'spokespeople', 'in', 'montreal', 'with', 'one', 'mohawk', 'women', 's', 'group', 'even', 'calling', 'for', 'the', 'cross', 'on', 'mount', 'royal']
#
# title : Mohawk Mothers Win Superior Court Judgement
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/recent-updates/mohawk-mothers-win-superior-court-judgement
# summary : This press release discusses the Superior Court judgement in favor of the Mohawk Mothers.
# tags : ['indigenous']
# first 100 out of 4842 characters:
# McGill and SQI Ordered to Comply with Settlement Agreement and Reinstate Expert Panel
# After obtaini
# first 30 out of 794 ws_tokens: ['mcgill', 'and', 'sqi', 'ordered', 'to', 'comply', 'with', 'settlement', 'agreement', 'and', 'reinstate', 'expert', 'panel', 'after', 'obtaining', 'one', 'year', 'ago', 'to', 'the', 'day', 'a', 'precedent', 'setting', 'injunction', 'halting', 'excavation', 'at', 'the', 'former']
#
# title : Mohawk Mothers Settlement at Allan Memorial Institute
# author : gareth madoc-jones
# publisher : city news
# URL : https://montreal.citynews.ca/2023/04/20/mohawk-mothers-settlement-allan-memorial-institute/
# summary : This article discusses the settlement reached by Mohawk mothers at the Allan Memorial Institute.
# tags : ['news', 'corporate']
# first 100 out of 3226 characters:
# A settlement agreement was reached Thursday between the Mohawk Mothers, an Indigenous group, and Mo
# first 30 out of 546 ws_tokens: ['a', 'settlement', 'agreement', 'was', 'reached', 'thursday', 'between', 'the', 'mohawk', 'mothers', 'an', 'indigenous', 'group', 'and', 'montreal', 's', 'mcgill', 'university', 'it', 'entails', 'an', 'archeological', 'plan', 'and', 'it', 's', 'for', 'the', 'archeology', 'it']
#
# title : Historic Human Remains Detection Dogs Detect Scent of Human Remains on the Old Royal Victoria Hospital Site in Montreal
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/recent-updates/historic-human-remains-detection-dogs-detect-scent-of-human-remains-on-the-old-royal-victoria-hospital-site-in-montreal
# summary : This press release discusses the detection of the scent of human remains at the old Royal Victoria Hospital site in Montreal by historic human remains detection dogs. The linked report was written by Kim Cooper.
# tags : ['indigenous']
# first 100 out of 2847 characters:
# See the attached report from the Ottawa Valley Search and Rescue Dog Association with the details o
# first 30 out of 493 ws_tokens: ['see', 'the', 'attached', 'report', 'from', 'the', 'ottawa', 'valley', 'search', 'and', 'rescue', 'dog', 'association', 'with', 'the', 'details', 'of', 'their', 'june', '9', '2023', 'search', 'of', 'the', 'old', 'royal', 'victoria', 'hospital', 'grounds', 'sqi']
#
# title : McGill's Royal Vic plans prompt call to check for unmarked graves
# author : T'Cha Dunlevy
# publisher : montreal gazette
# URL : https://montrealgazette.com/news/local-news/mcgills-royal-vic-plans-prompt-call-to-check-for-unmarked-graves
# summary : This article discusses the call for McGill University to check for unmarked graves at the Royal Victoria Hospital site, in light of their redevelopment plans.
# tags : ['news']
# first 100 out of 3856 characters:
# A group called the Mohawk Mothers (kanien’kehá:ka kahnistensera) is demanding “the immediate suspen
# first 30 out of 616 ws_tokens: ['a', 'group', 'called', 'the', 'mohawk', 'mothers', 'kanien', 'kehá', 'ka', 'kahnistensera', 'is', 'demanding', 'the', 'immediate', 'suspension', 'of', 'mcgill', 'university', 's', 'expansion', 'plan', 'for', 'the', 'old', 'royal', 'victoria', 'hospital', 'site', 'and', 'an']
#
# title : cadaver-dogs-sniff-out-potential-human-remains-near-old-royal-victoria-hospital-site
# author : Emelia Fournier
# publisher : aptn news
# URL : https://www.aptnnews.ca/national-news/cadaver-dogs-sniff-out-potential-human-remains-near-old-royal-victoria-hospital-site/
# summary : None
# tags : ['news', 'indigenous']
# first 100 out of 5939 characters:
# Cadaver dogs have detected potential human remains on McGill University grounds where a group calle
# first 30 out of 954 ws_tokens: ['cadaver', 'dogs', 'have', 'detected', 'potential', 'human', 'remains', 'on', 'mcgill', 'university', 'grounds', 'where', 'a', 'group', 'called', 'the', 'mohawk', 'mothers', 'believe', 'unmarked', 'graves', 'exist', 'on', 'june', '9', '2023', 'three', 'cadaver', 'dog', 'teams']
#
# title : Our Children Are Buried on These Grounds, Marchers at Old Royal Vic Site Say
# author : Jason Magder
# publisher : Montreal Gazette
# URL : https://montrealgazette.com/news/local-news/our-children-are-buried-on-these-grounds-marchers-at-old-royal-vic-site-say
# summary : This article reports on a march at the old Royal Vic site, where participants claim their children are buried.
# tags : ['news', 'montreal']
# first 100 out of 3829 characters:
# As the sun set and cars lined up for the usual nighttime commute on Pine Ave., a group of protester
# first 30 out of 651 ws_tokens: ['as', 'the', 'sun', 'set', 'and', 'cars', 'lined', 'up', 'for', 'the', 'usual', 'nighttime', 'commute', 'on', 'pine', 'ave', 'a', 'group', 'of', 'protesters', 'held', 'a', 'solemn', 'march', 'holding', 'candles', 'and', 'with', 'many', 'wearing']
#
# title : indigenous-women-lead-protest-calling-for-removal-of-cross-on-mount-royal
# author : max harrold
# publisher : ctv news
# URL : https://montreal.ctvnews.ca/indigenous-women-lead-protest-calling-for-removal-of-cross-on-mount-royal-1.6005108
# summary : None
# tags : ['news', 'corporate']
# first 100 out of 2021 characters:
# A group of Indigenous women staged a protest on Mount-Royal Wednesday against Pope Francis' histori
# first 30 out of 370 ws_tokens: ['a', 'group', 'of', 'indigenous', 'women', 'staged', 'a', 'protest', 'on', 'mount', 'royal', 'wednesday', 'against', 'pope', 'francis', 'historic', 'visit', 'to', 'canada', 'the', 'group', 'known', 'as', 'the', 'mohawk', 'mothers', 'said', 'an', 'apology', 'for']
#
# title : Mohawk Mothers Want Former Montreal Hospital Site Searched for Unmarked Graves
# author : Montreal Gazette
# publisher : Montreal Gazette
# URL : https://montrealgazette.com/news/local-news/mohawk-mothers-want-former-montreal-hospital-site-searched-for-unmarked-graves
# summary : This article discusses a petition from Ellen Atkin, who wants the former Montreal hospital site to be searched for unmarked graves.
# tags : ['news']
# first 100 out of 1878 characters:
# The group behind the recent push to search for unmarked graves at the site of the former Royal Vict
# first 30 out of 304 ws_tokens: ['the', 'group', 'behind', 'the', 'recent', 'push', 'to', 'search', 'for', 'unmarked', 'graves', 'at', 'the', 'site', 'of', 'the', 'former', 'royal', 'victoria', 'hospital', 'now', 'hopes', 'to', 'suspend', 'the', 'sale', 'of', 'another', 'former', 'montreal']
#
# title : Mohawk Mothers Return to Court September 14 as SQI Drill Holes at Royal Victoria Hospital
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/recent-updates/mohawk-mothers-return-to-court-september-14-as-sqi-drill-holes-at-royal-victoria-hospital
# summary : This press release discusses the return of the Mohawk Mothers to court on September 14, as the SQI drills holes at the Royal Victoria Hospital.
# tags : ['indigenous']
# first 100 out of 1594 characters:
# The Mohawk Mothers, also known as the Kahnistensera, held a press conference at the corner of avenu
# first 30 out of 246 ws_tokens: ['the', 'mohawk', 'mothers', 'also', 'known', 'as', 'the', 'kahnistensera', 'held', 'a', 'press', 'conference', 'at', 'the', 'corner', 'of', 'avenue', 'des', 'pins', 'and', 'doctor', 'penfield', 'on', 'september', '12', '2023', 'at', '2', '30pm', 'the']
#
# title : Mohawk Mothers Ask to Protect Potential Unmarked Burials
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/recent-updates/mohawk-mothers-ask-to-protect-potential-unmarked-burials
# summary : This press release is in response to the discovery by human remains detection dogs. It calls for the protection of potential unmarked burials.
# tags : ['indigenous']
# first 100 out of 5639 characters:
# Following the recent discovery of the scent of human remains by Historic Human Remains Detection Do
# first 30 out of 870 ws_tokens: ['following', 'the', 'recent', 'discovery', 'of', 'the', 'scent', 'of', 'human', 'remains', 'by', 'historic', 'human', 'remains', 'detection', 'dogs', 'hhrdd', 'on', 'the', 'grounds', 'of', 'the', 'old', 'royal', 'victoria', 'hospital', 'in', 'montreal', 'the', 'kanien']
#
# title : Immediate Suspension of Sale
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/recent-updates/immediate-suspension-of-sale
# summary : This press release calls for the immediate suspension of the sale of the former Montreal hospital site and contains links to further information about the search for unmarked graves.
# tags : ['indigenous']
# first 100 out of 474 characters:
# The Mohawk Mothers have sent formal notice to the City of Montreal and the government of Quebec dem
# first 30 out of 79 ws_tokens: ['the', 'mohawk', 'mothers', 'have', 'sent', 'formal', 'notice', 'to', 'the', 'city', 'of', 'montreal', 'and', 'the', 'government', 'of', 'quebec', 'demanding', 'immediate', 'suspension', 'of', 'the', 'sale', 'of', 'the', 'former', 'hôpital', 'de', 'la', 'miséricorde']
#
# title : dogs-find-evidence-of-human-remains-at-site-of-montreal-s-old-royal-victoria-hospital
# author : joe lofaro
# publisher : ctv news
# URL : https://montreal.ctvnews.ca/search-dogs-find-evidence-of-human-remains-at-site-of-montreal-s-old-royal-victoria-hospital-1.6462031
# summary : None
# tags : ['news', 'corporate']
# first 100 out of 4131 characters:
# Cadaver dogs conducting a search on the grounds of the Old Royal Victoria Hospital in Montreal have
# first 30 out of 683 ws_tokens: ['cadaver', 'dogs', 'conducting', 'a', 'search', 'on', 'the', 'grounds', 'of', 'the', 'old', 'royal', 'victoria', 'hospital', 'in', 'montreal', 'have', 'discovered', 'evidence', 'of', 'human', 'remains', 'according', 'to', 'a', 'new', 'report', 'a', 'group', 'of']
#
# title : historic-win-for-mohawk-mothers-in-lawsuit-against-mcgill-over-new-vic-project
# author : jasjot_grewal
# publisher : the tribune
# URL : https://www.thetribune.ca/news/historic-win-for-mohawk-mothers-in-lawsuit-against-mcgill-over-new-vic-project-01112022/
# summary : summary
# tags : ['news', 'student']
# first 100 out of 8939 characters:
# A Quebec Superior Court judge, Justice Gregory Moore, granted the Kanien’kehà:ka Kahnistensera (Moh
# first 30 out of 1459 ws_tokens: ['a', 'quebec', 'superior', 'court', 'judge', 'justice', 'gregory', 'moore', 'granted', 'the', 'kanien', 'kehà', 'ka', 'kahnistensera', 'mohawk', 'mothers', 'an', 'interlocutory', 'injunction', 'on', 'oct', '27', 'after', 'a', 'two', 'day', 'court', 'hearing', 'for', 'the']
#
# title : archeological-work-at-the-new-vic-site-dominates-mcgill-senate-meeting
# author : Lily_Cason
# publisher : the tribune
# URL : https://www.thetribune.ca/news/archeological-work-at-the-new-vic-site-dominates-mcgill-senate-meeting25102022/
# summary : During the university’s second Senate meeting of the academic year on Oct. 19, senators discussed the Kanien’kehá:ka Kahnistensera’s (Mohawk Mothers) legal dispute with McGill over the New Vic Project and the university’s COVID-19 protocols.
# tags : ['news', 'student']
# first 100 out of 4052 characters:
# During the university’s second Senate meeting of the academic year on Oct. 19, senators discussed t
# first 30 out of 635 ws_tokens: ['during', 'the', 'university', 's', 'second', 'senate', 'meeting', 'of', 'the', 'academic', 'year', 'on', 'oct', '19', 'senators', 'discussed', 'the', 'kanien', 'kehá', 'ka', 'kahnistensera', 's', 'mohawk', 'mothers', 'legal', 'dispute', 'with', 'mcgill', 'over', 'the']
#
# title : Petition to Investigate Unmarked Graves at McGill University
# author : Mohawk Mothers
# publisher : Change.org
# URL : https://www.change.org/p/mcgill-university-investigate-unmarked-graves-at-mcgill-university
# summary : This is a petition initiated by Ellen Atkin under the auspices of the Mohawk Mothers to investigate unmarked graves at McGill University.
# tags : ['indigenous']
# first 100 out of 1668 characters:
# Mohawk Mothers won several court injunctions to stop construction and investigate unmarked graves a
# first 30 out of 260 ws_tokens: ['mohawk', 'mothers', 'won', 'several', 'court', 'injunctions', 'to', 'stop', 'construction', 'and', 'investigate', 'unmarked', 'graves', 'at', 'mcgill', 'university', 'mcgill', 'has', 'fought', 'them', 'every', 'step', 'of', 'the', 'way', 'read', 'the', 'updates', 'for', 'details']
#
# title : indigenous-group-calls-out-papal-apology-calling-it-meaningless
# author : brittany henriques
# publisher : city news
# URL : https://montreal.citynews.ca/2022/07/27/indigenous-group-calls-out-papal-apology-calling-it-meaningless/
# summary : None
# tags : ['news', 'corporate']
# first 100 out of 3287 characters:
# “If everybody thought that was a solution, that apology they all would’ve been there. There’s no wa
# first 30 out of 621 ws_tokens: ['if', 'everybody', 'thought', 'that', 'was', 'a', 'solution', 'that', 'apology', 'they', 'all', 'would', 've', 'been', 'there', 'there', 's', 'no', 'way', 'you', 'could', 'drag', 'me', 'there', 'said', 'mohawk', 'mother', 'kwetiio', 'an', 'indigenous']
#
# title : The Site
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/the-site
# summary : None
# tags : ['indigenous']
# first 100 out of 2665 characters:
# Meaning “Two Mountains”, Tekanontak is the traditional Kanien'kehá:ka name of Mount Royal, at the h
# first 30 out of 428 ws_tokens: ['meaning', 'two', 'mountains', 'tekanontak', 'is', 'the', 'traditional', 'kanien', 'kehá', 'ka', 'name', 'of', 'mount', 'royal', 'at', 'the', 'heart', 'of', 'montreal', 'it', 'is', 'the', 'location', 'of', 'the', 'iroquoian', 'village', 'that', 'jacques', 'cartier']
#
# title : Trial on Unceded Land Smoke Screens vs Centuries of Resistance
# author : Take Back Tekanontak Committee
# publisher : Cultural Survival
# URL : https://www.culturalsurvival.org/news/trial-unceded-land-smoke-screens-vs-centuries-resistance
# summary : This article discusses the ongoing trial on unceded land, highlighting the contrast between deceptive tactics and centuries of indigenous resistance.
# tags : ['news', 'indigenous']
# first 100 out of 20178 characters:
# Despite an ongoing injunction in court by the kanien’kehá:ka kahnistensera (Mohawk Mothers) against
# first 30 out of 3269 ws_tokens: ['despite', 'an', 'ongoing', 'injunction', 'in', 'court', 'by', 'the', 'kanien', 'kehá', 'ka', 'kahnistensera', 'mohawk', 'mothers', 'against', 'mcgill', 'university', 'société', 'des', 'infrastructure', 'du', 'québec', 'ville', 'de', 'montréal', 'et', 'al', 'archeological', 'excavation', 'on']
#
# title : kahentinethas-challenge-to-mcgills-new-vic-project
# author : benjamin wexler
# publisher : the tribune
# URL : https://www.thetribune.ca/news/kahentinethas-challenge-to-mcgills-new-vic-project02112021/
# summary : None
# tags : ['news', 'student']
# first 100 out of 4512 characters:
# Kahentinetha, a Kanien’kehá:ka kahnistensera (Mohawk Mother) of the Bear Clan and founder of Mohawk
# first 30 out of 716 ws_tokens: ['kahentinetha', 'a', 'kanien', 'kehá', 'ka', 'kahnistensera', 'mohawk', 'mother', 'of', 'the', 'bear', 'clan', 'and', 'founder', 'of', 'mohawk', 'nation', 'news', 'is', 'demanding', 'the', 'suspension', 'of', 'mcgill', 's', 'new', 'vic', 'project', 'in', 'a']
#
# title : The Mission
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/the-mission
# summary : The Mohawk Mothers' goals and concerns
# tags : ['indigenous']
# first 100 out of 1287 characters:
# We are an Indigenous-led initiative committed to gathering information about the medical experiment
# first 30 out of 193 ws_tokens: ['we', 'are', 'an', 'indigenous', 'led', 'initiative', 'committed', 'to', 'gathering', 'information', 'about', 'the', 'medical', 'experiments', 'that', 'occurred', 'at', 'the', 'allen', 'memorial', 'institute', 'throughout', 'the', '1950s', 'and', '1960s', 'we', 'have', 'been', 'engaged']
#
# title : Mohawk Mothers Join Fight to Protect Irish Gravesite
# author : Eve Cable
# publisher : Eastern Door
# URL : https://easterndoor.com/2023/06/05/mohawk-mothers-join-fight-to-protect-irish-gravesite/
# summary : This article discusses the involvement of the Mohawk Mothers in the fight to protect the Black Rock gravesite.
# tags : ['indigenous', 'news']
# first 100 out of 5447 characters:
# After a triumph in court against some of Quebec and Canada’s biggest institutional bodies, the Kani
# first 30 out of 938 ws_tokens: ['after', 'a', 'triumph', 'in', 'court', 'against', 'some', 'of', 'quebec', 'and', 'canada', 's', 'biggest', 'institutional', 'bodies', 'the', 'kanien', 'kehá', 'ka', 'kahnistensera', 'mohawk', 'mothers', 'are', 'now', 'taking', 'on', 'another', 'political', 'fight', 'this']
#
# title : Press Release September 12, 2023
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://static1.squarespace.com/static/6449525c9a1ab06f2f1830cc/t/6500d6108e3845491c0ecf53/1694553616508/Kahnistensera+Press+Release+September+12%2C+2023%5B36901%5D.pdf
# summary : This is a press release issued by the Mohawk Mothers on September 12, 2023.
# tags : ['indigenous']
# first 100 out of 5757 characters:
# The Mohawk Mothers, also known as the Kahnistensera, will hold a press conference at the corner of
# first 30 out of 935 ws_tokens: ['the', 'mohawk', 'mothers', 'also', 'known', 'as', 'the', 'kahnistensera', 'will', 'hold', 'a', 'press', 'conference', 'at', 'the', 'corner', 'of', 'avenue', 'des', 'pins', 'and', 'doctor', 'penfield', 'on', 'september', '12', '2023', 'at', '2', '30pm']
#
# title : The Stakeholders
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/the-stake_holders
# summary : None
# tags : ['indigenous']
# first 100 out of 7672 characters:
# In Kanien'kehá:ka (Mohawk) language, Kahnistensera means “life givers.” It alludes to the umbilical
# first 30 out of 1141 ws_tokens: ['in', 'kanien', 'kehá', 'ka', 'mohawk', 'language', 'kahnistensera', 'means', 'life', 'givers', 'it', 'alludes', 'to', 'the', 'umbilical', 'cord', 'that', 'attaches', 'all', 'women', 'to', 'mother', 'earth', 'according', 'to', 'kaianerehkó', 'wa', 'the', 'great', 'law']
#
# title : Old Royal Victoria Hospital Project Remains
# author : cbc news
# publisher : cbc
# URL : https://www.cbc.ca/news/canada/montreal/old-royal-victoria-hospital-project-remains-1.6463685
# summary : This article discusses the ongoing project at the old Royal Victoria Hospital and its current status.
# tags : ['news', 'corporate']
# first 100 out of 2585 characters:
# Montreal's public consultation office is recommending that McGill University's plans to redevelop p
# first 30 out of 420 ws_tokens: ['montreal', 's', 'public', 'consultation', 'office', 'is', 'recommending', 'that', 'mcgill', 'university', 's', 'plans', 'to', 'redevelop', 'part', 'of', 'the', 'former', 'royal', 'victoria', 'hospital', 'move', 'forward', 'but', 'not', 'without', 'some', 'key', 'changes', 'a']
#
# title : The Challenge
# author : Mohawk Mothers
# publisher : Mohawk Mothers
# URL : https://www.mohawkmothers.ca/the-challenge
# summary : None
# tags : ['indigenous']
# first 100 out of 7100 characters:
# On October 27, 2022, the Mohawk Mothers won an important battle: the first-ever injunction obtained
# first 30 out of 1078 ws_tokens: ['on', 'october', '27', '2022', 'the', 'mohawk', 'mothers', 'won', 'an', 'important', 'battle', 'the', 'first', 'ever', 'injunction', 'obtained', 'by', 'self', 'represented', 'indigenous', 'peoples', 'in', 'a', 'canadian', 'court', 'following', 'their', 'own', 'indigenous', 'legal']
#
# title : Mohawk Mothers Win Injunction
# author : cbc
# publisher : cbc
# URL : https://www.cbc.ca/news/canada/montreal/mohawk-mothers-win-injunction-1.6632734
# summary : This article reports on the victory of Mohawk mothers who won an injunction in a significant legal case.
# tags : ['news', 'corporate']
# first 100 out of 4144 characters:
# A Quebec Superior Court judge has granted an emergency injunction to stop excavation work on the ol
# first 30 out of 672 ws_tokens: ['a', 'quebec', 'superior', 'court', 'judge', 'has', 'granted', 'an', 'emergency', 'injunction', 'to', 'stop', 'excavation', 'work', 'on', 'the', 'old', 'royal', 'victoria', 'hospital', 'site', 'in', 'montreal', 'as', 'requested', 'by', 'a', 'group', 'of', 'kanien']
#
# title : Mohawk Mothers at Royal Vic Site
# author : cbc
# publisher : cbc
# URL : https://www.cbc.ca/news/canada/montreal/mohawk-mothers-royal-vic-site-1.6817301
# summary : This article discusses the involvement of Mohawk mothers at the Royal Vic site.
# tags : ['news', 'corporate']
# first 100 out of 3891 characters:
# The Kanien'kehá:ka elders known as the Mohawk Mothers have reached a deal with the province to ensu
# first 30 out of 643 ws_tokens: ['the', 'kanien', 'kehá', 'ka', 'elders', 'known', 'as', 'the', 'mohawk', 'mothers', 'have', 'reached', 'a', 'deal', 'with', 'the', 'province', 'to', 'ensure', 'archaeological', 'excavations', 'will', 'take', 'place', 'on', 'the', 'site', 'of', 'the', 'former']
#
# title : Mohawk Mothers Investigation Unmarked Graves at McGill University
# author : Olivia O'Malley
# publisher : global news
# URL : https://globalnews.ca/news/8284327/mohawk-mothers-investigation-unmarked-graves-mcgill-university/
# summary : This article discusses the investigation led by Mohawk mothers into the unmarked graves at McGill University.
# tags : ['news', 'corporate']
# first 100 out of 2025 characters:
# Mohawk Mothers suspect there may be unmarked graves on McGill University’s campus.
# The group believ
# first 30 out of 327 ws_tokens: ['mohawk', 'mothers', 'suspect', 'there', 'may', 'be', 'unmarked', 'graves', 'on', 'mcgill', 'university', 's', 'campus', 'the', 'group', 'believes', 'they', 're', 'linked', 'to', 'controversial', 'psychological', 'experiments', 'conducted', 'there', 'in', 'the', '1950s', 'and', '1960s']
#
# title : Mohawk Mothers, McGill Reach Deal to Search for Graves at Site of
# author : globe and mail
# publisher : globe and mail
# URL : https://www.theglobeandmail.com/canada/article-mohawk-mothers-mcgill-reach-deal-to-search-for-graves-at-site-of/
# summary : This article reports on the agreement between Mohawk mothers and McGill University to search for graves at a specific site.
# tags : ['news', 'corporate']
# first 100 out of 3316 characters:
# McGill University and a group of Indigenous elders have reached a deal to search for the possibilit
# first 30 out of 535 ws_tokens: ['mcgill', 'university', 'and', 'a', 'group', 'of', 'indigenous', 'elders', 'have', 'reached', 'a', 'deal', 'to', 'search', 'for', 'the', 'possibility', 'of', 'unmarked', 'graves', 'at', 'the', 'former', 'site', 'of', 'a', 'montreal', 'hospital', 'following', 'a']
#
# title : Mohawk Mother at Montreal's Allan Memorial Institute
# author : alyssia rubertucci
# publisher : city news
# URL : https://montreal.citynews.ca/2022/11/02/mohawk-mother-montreals-allan-memorial-institute/
# summary : This article discusses the involvement of a Mohawk mother at Montreal's Allan Memorial Institute.
# tags : ['news', 'corporate']
# first 100 out of 2820 characters:
# A group of elders from Kahnawake – south of Montreal- known as the Mohawk mothers, were successful
# first 30 out of 486 ws_tokens: ['a', 'group', 'of', 'elders', 'from', 'kahnawake', 'south', 'of', 'montreal', 'known', 'as', 'the', 'mohawk', 'mothers', 'were', 'successful', 'in', 'getting', 'a', 'quebec', 'judge', 'to', 'stop', 'excavation', 'work', 'at', 'an', 'expansion', 'project', 'at']
#
# title : Mothers Force Royal Vic Dig Halt
# author : Eve Cable
# publisher : eastern door
# URL : https://easterndoor.com/2022/10/28/mothers-force-royal-vic-dig-halt/
# summary : This article discusses how mothers have managed to halt the digging at the Royal Vic site.
# tags : ['news', 'indigenous']
# first 100 out of 7461 characters:
# As the Kanien’kehá:ka Kahnistensera (Mohawk Mothers) close out two days in Quebec’s Superior Court
# first 30 out of 1243 ws_tokens: ['as', 'the', 'kanien', 'kehá', 'ka', 'kahnistensera', 'mohawk', 'mothers', 'close', 'out', 'two', 'days', 'in', 'quebec', 's', 'superior', 'court', 'this', 'week', 'a', 'judge', 'has', 'ruled', 'that', 'the', 'archaeological', 'firm', 'arkéos', 'must', 'stop']
#
# title : Evidence of Bodies Found at Royal Vic During Dogs Search
# author : Matthew Lapierre
# publisher : CBC
# URL : https://www.cbc.ca/news/canada/montreal/royal-vic-bodies-evidence-found-dogs-search-1.6892583
# summary : This article reports on the discovery of evidence of bodies at the Royal Vic site during a search conducted with dogs.
# tags : ['news', 'corporate']
# first 100 out of 4204 characters:
# Cadaver dogs have identified possible evidence of human remains on the grounds of Montreal's old Ro
# first 30 out of 705 ws_tokens: ['cadaver', 'dogs', 'have', 'identified', 'possible', 'evidence', 'of', 'human', 'remains', 'on', 'the', 'grounds', 'of', 'montreal', 's', 'old', 'royal', 'victoria', 'hospital', 'a', 'sprawling', 'network', 'of', 'now', 'vacant', 'buildings', 'some', 'dating', 'back', '140']
#
# title : arkeos-at-royal-vic
# author : saylor catlin, emma bainbridge
# publisher : mcgill daily
# URL : https://www.mcgilldaily.com/2022/10/arkeos-at-royal-vic/
# summary : This is a brief summary of the document.
# tags : ['news', 'student']
# first 100 out of 1396 characters:
# This week, archaeological firm Arkéos began investigating the site of the Royal Victoria Hospital (
# first 30 out of 220 ws_tokens: ['this', 'week', 'archaeological', 'firm', 'arkéos', 'began', 'investigating', 'the', 'site', 'of', 'the', 'royal', 'victoria', 'hospital', 'rvh', 'on', 'behalf', 'of', 'mcgill', 'university', 'mcgill', 'plans', 'to', 'turn', 'the', 'former', 'hospital', 'into', 'a', 'new']
#
# title : Montreal Unmarked Graves Search by Mohawk Mothers
# author : amanda jelowicki
# publisher : global news
# URL : https://globalnews.ca/news/9639569/montreal-unmarked-graves-search-mohawk-mothers/
# summary : This article discusses the search for unmarked graves in Montreal conducted by Mohawk mothers.
# tags : ['news', 'corporate']
# first 100 out of 4291 characters:
# Archeological work on the site of the former Royal Victoria Hospital and Allan Memorial Institute h
# first 30 out of 709 ws_tokens: ['archeological', 'work', 'on', 'the', 'site', 'of', 'the', 'former', 'royal', 'victoria', 'hospital', 'and', 'allan', 'memorial', 'institute', 'has', 'begun', 'with', 'experts', 'mapping', 'the', 'area', 'to', 'search', 'for', 'the', 'remains', 'of', 'indigenous', 'children']
#
# title : Quebec Judge Says McGill Work Halted to Avoid Irreparable Harm to Mohawk Plaintiffs
# author : Marisela Amador
# publisher : Global News
# URL : https://globalnews.ca/news/9242445/quebec-judge-says-mcgill-work-halted-to-avoid-irreparable-harm-to-mohawk-plaintiffs/
# summary : This article reports on a Quebec judge's decision to halt work at McGill to prevent potential irreparable harm to Mohawk plaintiffs.
# tags : ['news', 'corporate']
# first 100 out of 4275 characters:
# McGill University said Tuesday it will begin discussions with an Indigenous group that has raised c
# first 30 out of 670 ws_tokens: ['mcgill', 'university', 'said', 'tuesday', 'it', 'will', 'begin', 'discussions', 'with', 'an', 'indigenous', 'group', 'that', 'has', 'raised', 'concerns', 'about', 'unmarked', 'graves', 'after', 'a', 'court', 'ruled', 'that', 'excavation', 'work', 'on', 'a', 'university', 'expansion']
#
# title : Royal Victoria Hospital Plans Approval
# author : Phil Carpenter
# publisher : Global News
# URL : https://globalnews.ca/news/8866520/royal-victoria-hospital-plans-approval/
# summary : This article discusses the approval of the plans for the Royal Victoria Hospital.
# tags : ['news', 'corporate']
# first 100 out of 1748 characters:
# The former Royal Victoria Hospital site is one step closer to becoming a McGill University research
# first 30 out of 291 ws_tokens: ['the', 'former', 'royal', 'victoria', 'hospital', 'site', 'is', 'one', 'step', 'closer', 'to', 'becoming', 'a', 'mcgill', 'university', 'research', 'facility', 'following', 'hearings', 'last', 'september', 'by', 'the', 'l', 'office', 'de', 'consultation', 'publique', 'de', 'montréal']
#
# title : Mohawk Mothers Blazing a Trail
# author : steve bonspiel
# publisher : eastern door
# URL : https://easterndoor.com/2022/11/07/mohawk-mothers-blazing-a-trail/
# summary : This article highlights the efforts of Mohawk mothers in leading community initiatives and advocating for indigenous rights.
# tags : ['news', 'indigenous']
# first 100 out of 3742 characters:
# To challenge a giant head on is one thing. To do it representing yourselves in a foreign system, wi
# first 30 out of 672 ws_tokens: ['to', 'challenge', 'a', 'giant', 'head', 'on', 'is', 'one', 'thing', 'to', 'do', 'it', 'representing', 'yourselves', 'in', 'a', 'foreign', 'system', 'with', 'no', 'lawyers', 'and', 'nothing', 'but', 'a', 'hunch', 'powerful', 'protective', 'instincts', 'and']

# %%
## how many ws words
vocab_set = Counter()
for document in corpus:
    vocab = Counter(corpus[document]['ws_tokens'])
    vocab_set = set(vocab)
    print(f"length of vocab: {len(vocab_set)}")
# Out:
# length of vocab: 361
# length of vocab: 511
# length of vocab: 196
# length of vocab: 432
# length of vocab: 191
# length of vocab: 365
# length of vocab: 243
# length of vocab: 217
# length of vocab: 304
# length of vocab: 391
# length of vocab: 304
# length of vocab: 178
# length of vocab: 151
# length of vocab: 151
# length of vocab: 395
# length of vocab: 57
# length of vocab: 335
# length of vocab: 566
# length of vocab: 320
# length of vocab: 161
# length of vocab: 258
# length of vocab: 246
# length of vocab: 1074
# length of vocab: 325
# length of vocab: 125
# length of vocab: 395
# length of vocab: 418
# length of vocab: 486
# length of vocab: 233
# length of vocab: 454
# length of vocab: 318
# length of vocab: 290
# length of vocab: 188
# length of vocab: 267
# length of vocab: 247
# length of vocab: 492
# length of vocab: 319
# length of vocab: 145
# length of vocab: 311
# length of vocab: 308
# length of vocab: 174
# length of vocab: 331

# %%
import re, collections

def get_stats(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return pairs

def merge_vocab(pair, v_in):
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]
    return v_out

def byte_pair_tokenizer(string, vocab_size):
    # Initialize vocabulary
    vocab = collections.defaultdict(int)
    words = string.split()
    for word in words:
        vocab[' '.join(list(word)) + ' </w>'] = 1

    for i in range(vocab_size):
        pairs = get_stats(vocab)
        if not pairs:
            break
        best = max(pairs, key=pairs.get)
        vocab = merge_vocab(best, vocab)

    # Tokenize the string
    tokens = [word for word in vocab.keys()]
    tokens = [re.sub(r' </w>', '', token) for token in tokens]

    return tokens

# Test the tokenizer
tokens = byte_pair_tokenizer("Hello, world!", 100)
print(tokens)

# %%
all_tokens = []
for document in corpus:
    all_tokens += corpus[document]['ws_tokens']

# %%
all_tokens = [t.lower() for t in all_tokens]
print(f"num tokens: {len(all_tokens)} \n num unique tokens: {len(set(all_tokens))} \n first 100 tokens: {all_tokens[:100]}")
# Out:
# num tokens: 29843
#  num unique tokens: 3793
#  first 100 tokens: ['a', 'spokesperson', 'for', 'the', 'mohawk', 'mothers', 'or', 'kahnistensera', 'says', 'the', 'group', 'feels', 'pushed', 'aside', 'in', 'the', 'search', 'for', 'unmarked', 'graves', 'on', 'a', 'site', 'owned', 'by', 'société', 'québécoise', 'des', 'infrastructures', 'or', 'sqi', 'mcgill', 'says', 'it', 'leases', 'part', 'of', 'the', 'property', 'the', 'process', 'can', 'no', 'longer', 'by', 'any', 'means', 'be', 'considered', 'indigenous', 'led', 'as', 'the', 'sqi', 'and', 'mcgill', 'attempt', 'to', 'control', 'the', 'whole', 'process', 'reducing', 'the', 'role', 'of', 'indigenous', 'people', 'to', 'performing', 'ceremonies', 'on', 'the', 'site', 'said', 'kahentinetha', 'one', 'of', 'the', 'mothers', 'who', 'added', 'that', 'they', 'feel', 'blindsided', 'by', 'the', 'communications', 'that', 'happened', 'without', 'consulting', 'them', 'quebec', 's', 'infrastructure', 'society', 'or', 'sqi']

# %%
string = " ".join(all_tokens)
print(f"first 100 characters: {string[:100]}")
# Out:
# first 100 characters: a spokesperson for the mohawk mothers or kahnistensera says the group feels pushed aside in the sear

# %%
import re, collections

def get_stats(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return pairs

def merge_vocab(pair, v_in):
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]
    return v_out

def byte_pair_tokenizer(string, vocab_size):
    # Initialize vocabulary
    vocab = collections.defaultdict(int)
    words = string.split()
    for word in words:
        vocab[' '.join(list(word)) + ' </w>'] = 1

    for i in range(vocab_size):
        pairs = get_stats(vocab)
        if not pairs:
            break
        best = max(pairs, key=pairs.get)
        vocab = merge_vocab(best, vocab)

    # Tokenize the string
    tokens = [word for word in vocab.keys()]
    tokens = [re.sub(r' </w>', '', token) for token in tokens]

    return tokens

# Test the tokenizer
tokens = byte_pair_tokenizer(string, 4000)
print(tokens)
# Out:
# ['a</w>', 'spokesperson</w>', 'for</w>', 'the</w>', 'mohawk</w>', 'mothers</w>', 'or</w>', 'kahnistensera</w>', 'says</w>', 'group</w>', 'feels</w>', 'pushed</w>', 'aside</w>', 'in</w>', 'search</w>', 'unmarked</w>', 'graves</w>', 'on</w>', 'site</w>', 'owned</w>', 'by</w>', 'société</w>', 'québécoise</w>', 'des</w>', 'infrastructures</w>', 'sqi</w>', 'mcgill</w>', 'it</w>', 'leases</w>', 'part</w>', 'of</w>', 'property</w>', 'process</w>', 'can</w>', 'no</w>', 'longer</w>', 'any</w>', 'means</w>', 'be</w>', 'considered</w>', 'indigenous</w>', 'led</w>', 'as</w>', 'and</w>', 'attempt</w>', 'to</w>', 'control</w>', 'whole</w>', 'reducing</w>', 'role</w>', 'people</w>', 'performing</w>', 'ceremonies</w>', 'said</w>', 'kahentinetha</w>', 'one</w>', 'who</w>', 'added</w>', 'that</w>', 'they</w>', 'feel</w>', 'blindsided</w>', 'communications</w>', 'happened</w>', 'without</w>', 'consulting</w>', 'them</w>', 'quebec</w>', 's</w>', 'infrastructure</w>', 'society</w>', 'both</w>', 'put</w>', 'out</w>', 'statements</w>', 'aug</w>', '3</w>', 'saying</w>', 'nine</w>', 'potential</w>', 'gravesites</w>', 'were</w>', 'identified</w>', 'through</w>', 'ground</w>', 'penetrating</w>', 'radar</w>', 'gpr</w>', 'excluded</w>', 'information</w>', 'according</w>', 'geoscan</w>', 'report</w>', 'is</w>', 'possible</w>', 'some</w>', 'unknown</w>', 'features</w>', 'may</w>', 'particularly</w>', 'case</w>', 'older</w>', 'burials</w>', 'coffins</w>', 'also</w>', 'possibly</w>', 'child</w>', 'size</w>', 'archeologists</w>', 'have</w>', 'been</w>', 'very</w>', 'informative</w>', 'but</w>', 'there</w>', 'often</w>', 'delay</w>', 'receiving</w>', 'important</w>', 'reports</w>', 'only</w>', 'way</w>', 'we</w>', 'find</w>', 'right</w>', 'because</w>', 'are</w>', 'not</w>', 'told</w>', 'i</w>', 'don</w>', 't</w>', 'know</w>', 'why</w>', 'material</w>', 'goes</w>', 'then</w>', 'distribute</w>', 'want</w>', 'eventually</w>', 'get</w>', 'copy</w>', 'she</w>', 'seems</w>', 'like</w>', 'this</w>', 'violating</w>', 'court</w>', 'order</w>', 'present</w>', 'when</w>', 'dug</w>', 'up</w>', 'woman</w>', 'dress</w>', 'pair</w>', 'children</w>', 'shoes</w>', 'style</w>', 'dating</w>', 'back</w>', 'around</w>', '1940s</w>', 'archeologist</w>', 'panel</w>', 'appointed</w>', 'settlement</w>', 'agreement</w>', 'need</w>', 'appoint</w>', 'forensic</w>', 'specialist</w>', 'handle</w>', 'these</w>', 'items</w>', 'something</w>', 'has</w>', 'refused</w>', 'researcher</w>', 'philippe</w>', 'blouin</w>', 'now</w>', 'officially</w>', 'even</w>', 'though</w>', 'was</w>', 'recommendation</w>', 'from</w>', 'their</w>', 'recommendations</w>', 'supposed</w>', 'binding</w>', 'per</w>', 'he</w>', 'an</w>', 'email</w>', 'statement</w>', 'aptn</w>', 'news</w>', 'stated</w>', 'bioarcheologist</w>', 'archeological</w>', 'works</w>', 'underway</w>', 'did</w>', 'say</w>', 'whether</w>', 'trained</w>', 'handling</w>', 'potentially</w>', 'criminal</w>', 'evidence</w>', 'found</w>', 'just</w>', 'few</w>', 'inches</w>', 'inside</w>', 'plastic</w>', 'bag</w>', 'tamper</w>', 'proof</w>', 'stand</w>', 'many</w>', 'chances</w>', 'comes</w>', 'chain</w>', 'custody</w>', 'preserved</w>', 'prosecution</w>', 'successful</w>', 'left</w>', 'partially</w>', 'covered</w>', 'piles</w>', 'dirt</w>', 'sit</w>', 'rain</w>', 'since</w>', 'july</w>', '25</w>', 'where</w>', 'sniffer</w>', 'dogs</w>', 'detected</w>', 'scent</w>', 'human</w>', 'remains</w>', 'early</w>', 'june</w>', 'sifted</w>', 'respected</w>', 'sift</w>', 'extracted</w>', 'sniffed</w>', 'target</w>', 'immediately</w>', 'could</w>', 'midst</w>', 'being</w>', 'ignored</w>', 'despite</w>', 'publicly</w>', 'stating</w>', 'support</w>', 'commitment</w>', 'reconciliation</w>', 'unilaterally</w>', 'deemed</w>', 'mandate</w>', 'terminated</w>', 'would</w>', 'mean</w>', 'continue</w>', 'with</w>', 'firm</w>', 'ethnoscope</w>', 'guided</w>', 'rather</w>', 'than</w>', 'expert</w>', 'had</w>', 'submit</w>', 'two</w>', 'submitted</w>', '8</w>', 'other</w>', '17< ...

# %%
import re, collections

def get_stats(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return pairs

def merge_vocab(pair, v_in):
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]
    return v_out

def byte_pair_tokenizer(string, vocab_size, lexicon):
    # Initialize vocabulary
    vocab = collections.defaultdict(int)
    words = string.split()
    for word in words:
        vocab[' '.join(list(word)) + ' </w>'] = 1

    # Add entities and morphemes from the lexicon to the vocabulary
    for category in lexicon.values():
        for item in category:
            vocab[' '.join(list(item)) + ' </w>'] = 1

    for i in range(vocab_size):
        pairs = get_stats(vocab)
        if not pairs:
            break
        best = max(pairs, key=pairs.get)
        vocab = merge_vocab(best, vocab)

    # Tokenize the string
    tokens = [word for word in vocab.keys()]
    tokens = [re.sub(r' </w>', '', token) for token in tokens]

    return tokens

# Define a lexicon
lexicon = {
    'entities': ['the mowhawk mothers</w>', 'khanistensera'],
    'morphemes': ['ing', 'ed', 's', 'ness', 'less', 'ful', 'ly', "n't", "'m", "'ll", "'s", "'ve", "'re", "'d"]
}

# Test the tokenizer
tokens = byte_pair_tokenizer(string, 3000, lexicon)
print(tokens)
# Out:
# ['a</w>', 'spokesperson</w>', 'for</w>', 'the</w>', 'mohawk</w>', 'mothers</w>', 'or</w>', 'kahnistensera</w>', 'says</w>', 'group</w>', 'feels</w>', 'pushed</w>', 'aside</w>', 'in</w>', 'search</w>', 'unmarked</w>', 'graves</w>', 'on</w>', 'site</w>', 'owned</w>', 'by</w>', 'société</w>', 'québécoise</w>', 'des</w>', 'infrastructures</w>', 'sqi</w>', 'mcgill</w>', 'it</w>', 'leases</w>', 'part</w>', 'of</w>', 'property</w>', 'process</w>', 'can</w>', 'no</w>', 'longer</w>', 'any</w>', 'means</w>', 'be</w>', 'considered</w>', 'indigenous</w>', 'led</w>', 'as</w>', 'and</w>', 'attempt</w>', 'to</w>', 'control</w>', 'whole</w>', 'reducing</w>', 'role</w>', 'people</w>', 'performing</w>', 'ceremonies</w>', 'said</w>', 'kahentinetha</w>', 'one</w>', 'who</w>', 'added</w>', 'that</w>', 'they</w>', 'feel</w>', 'blindsided</w>', 'communications</w>', 'happened</w>', 'without</w>', 'consulting</w>', 'them</w>', 'quebec</w>', 's</w>', 'infrastructure</w>', 'society</w>', 'both</w>', 'put</w>', 'out</w>', 'statements</w>', 'aug</w>', '3</w>', 'saying</w>', 'nine</w>', 'potential</w>', 'gravesites</w>', 'were</w>', 'identified</w>', 'through</w>', 'ground</w>', 'penetrating</w>', 'radar</w>', 'gpr</w>', 'excluded</w>', 'information</w>', 'according</w>', 'geoscan</w>', 'report</w>', 'is</w>', 'possible</w>', 'some</w>', 'unknown</w>', 'features</w>', 'may</w>', 'particularly</w>', 'case</w>', 'older</w>', 'burials</w>', 'coffins</w>', 'also</w>', 'possibly</w>', 'child</w>', 'size</w>', 'archeologists</w>', 'have</w>', 'been</w>', 'very</w>', 'informative</w>', 'but</w>', 'there</w>', 'often</w>', 'delay</w>', 'receiving</w>', 'important</w>', 'reports</w>', 'only</w>', 'way</w>', 'we</w>', 'find</w>', 'right</w>', 'because</w>', 'are</w>', 'not</w>', 'told</w>', 'i</w>', 'don</w>', 't</w>', 'know</w>', 'why</w>', 'material</w>', 'goes</w>', 'then</w>', 'distribute</w>', 'want</w>', 'eventually</w>', 'get</w>', 'copy</w>', 'she</w>', 'seems</w>', 'like</w>', 'this</w>', 'violating</w>', 'court</w>', 'order</w>', 'present</w>', 'when</w>', 'dug</w>', 'up</w>', 'woman</w>', 'dress</w>', 'pair</w>', 'children</w>', 'shoes</w>', 'style</w>', 'dating</w>', 'back</w>', 'around</w>', '1940s</w>', 'archeologist</w>', 'panel</w>', 'appointed</w>', 'settlement</w>', 'agreement</w>', 'need</w>', 'appoint</w>', 'forensic</w>', 'specialist</w>', 'handle</w>', 'these</w>', 'items</w>', 'something</w>', 'has</w>', 'refused</w>', 'researcher</w>', 'philippe</w>', 'blouin</w>', 'now</w>', 'officially</w>', 'even</w>', 'though</w>', 'was</w>', 'recommendation</w>', 'from</w>', 'their</w>', 'recommendations</w>', 'supposed</w>', 'binding</w>', 'per</w>', 'he</w>', 'an</w>', 'email</w>', 'statement</w>', 'aptn</w>', 'news</w>', 'stated</w>', 'bioarcheologist</w>', 'archeological</w>', 'works</w>', 'underway</w>', 'did</w>', 'say</w>', 'whether</w>', 'trained</w>', 'handling</w>', 'potentially</w>', 'criminal</w>', 'evidence</w>', 'found</w>', 'just</w>', 'few</w>', 'inches</w>', 'inside</w>', 'plastic</w>', 'bag</w>', 'tamper</w>', 'proof</w>', 'stand</w>', 'many</w>', 'chances</w>', 'comes</w>', 'chain</w>', 'custody</w>', 'preserved</w>', 'prosecution</w>', 'successful</w>', 'left</w>', 'partially</w>', 'covered</w>', 'piles</w>', 'dirt</w>', 'sit</w>', 'rain</w>', 'since</w>', 'july</w>', '25</w>', 'where</w>', 'sniffer</w>', 'dogs</w>', 'detected</w>', 'scent</w>', 'human</w>', 'remains</w>', 'early</w>', 'june</w>', 'sifted</w>', 'respected</w>', 'sift</w>', 'extracted</w>', 'sniffed</w>', 'target</w>', 'immediately</w>', 'could</w>', 'midst</w>', 'being</w>', 'ignored</w>', 'despite</w>', 'publicly</w>', 'stating</w>', 'support</w>', 'commitment</w>', 'reconciliation</w>', 'unilaterally</w>', 'deemed</w>', 'mandate</w>', 'terminated</w>', 'would</w>', 'mean</w>', 'continue</w>', 'with</w>', 'firm</w>', 'ethnoscope</w>', 'guided</w>', 'rather</w>', 'than</w>', 'expert</w>', 'had</w>', 'submit</w>', 'two</w>', 'submitted</w>', '8</w>', 'other</w>', '17< ...

# %%
import re, collections

def byte_pair_tokenizer(string, vocab_size, lexicon):
    # Initialize vocabulary
    vocab = collections.defaultdict(int)
    words = string.split()
    for word in words:
        vocab[' '.join(list(word)) + ' </w>'] = 1

    # Add entities and morphemes from the lexicon to the vocabulary
    for category in lexicon.values():
        for item in category:
            if ' ' in item:  # Treat entities as single words
                vocab[item + ' </w>'] = 1
            else:
                vocab[' '.join(list(item)) + ' </w>'] = 1

    for i in range(vocab_size):
        pairs = get_stats(vocab)
        if not pairs:
            break
        best = max(pairs, key=pairs.get)
        vocab = merge_vocab(best, vocab)

    # Tokenize the string
    tokens = [word for word in vocab.keys()]
    tokens = [re.sub(r' </w>', '', token) for token in tokens]

    return tokens

# Test the tokenizer
tokens = byte_pair_tokenizer(string, 300, lexicon)
print(tokens)
# Out:
# ['a</w>', 's po k es per s on</w>', 'for', 'th e</w>', 'mo h aw k</w>', 'mo th ers</w>', 'or</w>', 'ka h n ist en ser a</w>', 's ay s</w>', 'g ro u p</w>', 'fe el s</w>', 'p us h ed</w>', 'a sid e</w>', 'in</w>', 'se arch', 'un mar ked</w>', 'g ra ves</w>', 'on</w>', 'si te</w>', 'ow n ed</w>', 'b y</w>', 'so ci é t é', 'qu é b é co is e</w>', 'd es</w>', 'in f ra struc tu res</w>', 's q i', 'm c g il l</w>', 'it</w>', 'le as es</w>', 'par t</w>', 'o f</w>', 'pro per ty</w>', 'pro c ess</w>', 'c an</w>', 'no', 'l on g er</w>', 'an y</w>', 'me ans</w>', 'b e</w>', 'con si der ed</w>', 'in di gen ous</w>', 'l ed</w>', 'a s</w>', 'and</w>', 'att em p t</w>', 'to', 'cont ro l</w>', 'wh ol e</w>', 're duc ing</w>', 'ro le</w>', 'pe op le</w>', 'per form ing</w>', 'c er em on ies</w>', 'sa i d</w>', 'ka h ent in e th a</w>', 'one</w>', 'w ho', 'ad ded</w>', 'th a t</w>', 'th e y</w>', 'fe el</w>', 'bl in d si ded</w>', 'comm un ic ations</w>', 'h ap pen ed</w>', 'w it h ou t</w>', 'con s ul ting</w>', 'th e m</w>', 'qu e b ec', 's</w>', 'in f ra struc tur e</w>', 'so ci e ty</w>', 'bo th</w>', 'pu t</w>', 'ou t</w>', 'st at e ments</w>', 'au g</w>', '3', 's ay ing</w>', 'n ine</w>', 'po t enti al</w>', 'g ra ve si t es</w>', 'w er e</w>', 'id enti fi ed</w>', 'th ro u gh', 'g roun d</w>', 'pen e tr ating</w>', 'ra d ar</w>', 'g pr', 'ex cl u ded</w>', 'in form ation</w>', 'ac cor ding</w>', 'ge o sc an</w>', 're por t</w>', 'i s</w>', 'po s si b le</w>', 'so m e</w>', 'un k n ow n</w>', 'fe at u res</w>', 'm ay</w>', 'par ti c ul ar ly</w>', 'c as e</w>', 'ol der</w>', 'b ur i als</w>', 'co ff in s</w>', 'al so', 'po s si b ly</w>', 'ch il d</w>', 'si z e</w>', 'arch eolog ist s</w>', 'h a ve</w>', 'be en</w>', 'ver y</w>', 'in form ati ve</w>', 'bu t</w>', 'th er e</w>', 'o f t en</w>', 'd el ay</w>', 'rec e i v ing</w>', 'im por t ant</w>', 're por ts</w>', 'on ly</w>', 'w ay</w>', 'w e</w>', 'fin d</w>', 'ri ght</w>', 'b ec a us e</w>', 'ar e</w>', 'no t</w>', 't ol d</w>', 'i', 'd on</w>', 't</w>', 'k n ow', 'wh y</w>', 'm at er ial</w>', 'go es</w>', 'th en</w>', 'di st ri bu te</w>', 'w ant</w>', 'e ven tu ally</w>', 'ge t</w>', 'co p y</w>', 'sh e</w>', 'se em s</w>', 'li k e</w>', 'th i s</w>', 'vi ol ating</w>', 'co ur t</w>', 'or der</w>', 'pres ent</w>', 'wh en</w>', 'du g</w>', 'u p</w>', 'w o m an</w>', 'd res s</w>', 'p a ir', 'ch il d r en</w>', 'sh o es</w>', 'st y le</w>', 'd ating</w>', 'b ac k</w>', 'ar o un d</w>', '19 4 0 s</w>', 'arch eolog ist</w>', 'p an el</w>', 'ap po in ted</w>', 'se t t le ment</w>', 'ag re e ment</w>', 'ne ed</w>', 'ap po in t</w>', 'for en si c', 'spec i al ist</w>', 'h and le</w>', 'th es e</w>', 'it em s</w>', 'so me th ing</w>', 'h a s</w>', 'ref us ed</w>', 'res e arch er</w>', 'ph il i p p e</w>', 'b lo u in</w>', 'n ow', 'off ic i ally</w>', 'e v en</w>', 'th ou gh', 'w a s</w>', 're com men d ation</w>', 'f ro m</w>', 'th e ir', 're com men d ations</w>', 'su p po sed</w>', 'b in ding</w>', 'p er</w>', 'h e</w>', 'an</w>', 'em ail', 'st at e ment</w>', 'ap t n</w>', 'ne w s</w>', 'st ated</w>', 'b i o arch eolog ist</w>', 'arch eolog ical</w>', 'wor ks</w>', 'under w ay</w>', 'di d</w>', 's ay</w>', 'wh e th er</w>', 'tra in ed</w>', 'h and ling</w>', 'po t enti ally</w>', 'c ri min al</w>', 'e vi d ence</w>', 'fo un d</w>', 'j us t</w>', 'fe w</w>', 'in ch es</w>', 'in sid e</w>', 'pl as ti c', 'b a g</w>', 't am p er</w>', 'pro o f</w>', 'st and</w>', 'm an y</w>', 'ch an ces</w>', 'com es</w>', 'ch ain</w>', 'c u st o d y</w>', 'pres er ved</w>', 'pro s ec u tion</w>', 'su c c ess ful</w>', 'le f t</w>', 'par ti ally</w>', 'co ver ed</w>', 'p il es</w>', 'di r t</w>', 'si t</w>', 'ra in</w>', 's in ce</w>', 'j u ly</w>', '2 5', 'wh er e</w>', 's ni ff er</w>', 'do g s</w>', 'de tec ted</w>', 'sc ent</w>', 'h um an</w>', 're m ain s</w>', 'e ar ly</w>', 'j un e</w>', 'si f ted</w>', 'res pec ted</w>', 'si f t</w>', 'ex tr ac ted</w>', 's ni ff ed</w>', 't ar ge t</w>', 'im me d ...

# %%
decoded_tokens = [t[:-4] if t.endswith('</w>') else t for t in tokens]
decoded_tokens
# Out:
# ['a',
#  'spokesperson',
#  'for',
#  'the',
#  'mohawk',
#  'mothers',
#  'or',
#  'kahnistensera',
#  'says',
#  'group',
#  'feels',
#  'pushed',
#  'aside',
#  'in',
#  'search',
#  'unmarked',
#  'graves',
#  'on',
#  'site',
#  'owned',
#  'by',
#  'société',
#  'québécoise',
#  'des',
#  'infrastructures',
#  'sqi',
#  'mcgill',
#  'it',
#  'leases',
#  'part',
#  'of',
#  'property',
#  'process',
#  'can',
#  'no',
#  'longer',
#  'any',
#  'means',
#  'be',
#  'considered',
#  'indigenous',
#  'led',
#  'as',
#  'and',
#  'attempt',
#  'to',
#  'control',
#  'whole',
#  'reducing',
#  'role',
#  'people',
#  'performing',
#  'ceremonies',
#  'said',
#  'kahentinetha',
#  'one',
#  'who',
#  'added',
#  'that',
#  'they',
#  'feel',
#  'blindsided',
#  'communications',
#  'happened',
#  'without',
#  'consulting',
#  'them',
#  'quebec',
#  's',
#  'infrastructure',
#  'society',
#  'both',
#  'put',
#  'out',
#  'statements',
#  'aug',
#  '3',
#  'saying',
#  'nine',
#  'potential',
#  'gravesites',
#  'were',
#  'identified',
#  'through',
#  'ground',
#  'penetrating',
#  'radar',
#  'gpr',
#  'excluded',
#  'information',
#  'according',
#  'geoscan',
#  'report',
#  'is',
#  'possible',
#  'some',
#  'unknown',
#  'features',
#  'may',
#  'particularly',
#  'case',
#  'older',
#  'burials',
#  'coffins',
#  'also',
#  'possibly',
#  'child',
#  'size',
#  'archeologists',
#  'have',
#  'been',
#  'very',
#  'informative',
#  'but',
#  'there',
#  'often',
#  'delay',
#  'receiving',
#  'important',
#  'reports',
#  'only',
#  'way',
#  'we',
#  'find',
#  'right',
#  'because',
#  'are',
#  'not',
#  'told',
#  'i',
#  'don',
#  't',
#  'know',
#  'why',
#  'material',
#  'goes',
#  'then',
#  'distribute',
#  'want',
#  'eventually',
#  'get',
#  'copy',
#  'she',
#  'seems',
#  'like',
#  'this',
#  'violating',
#  'court',
#  'order',
#  'present',
#  'when',
#  'dug',
#  'up',
#  'woman',
#  'dress',
#  'pair',
#  'children',
#  'shoes',
#  'style',
#  'dating',
#  'back',
#  'around',
#  '1940s',
#  'archeologist',
#  'panel',
#  'appointed',
#  'settlement',
#  'agreement',
#  'need',
#  'appoint',
#  'forensic',
#  'specialist',
#  'handle',
#  'these',
#  'items',
#  'something',
#  'has',
#  'refused',
#  'researcher',
#  'philippe',
#  'blouin',
#  'now',
#  'officially',
#  'even',
#  'though',
#  'was',
#  'recommendation',
#  'from',
#  'their',
#  'recommendations',
#  'supposed',
#  'binding',
#  'per',
#  'he',
#  'an',
#  'email',
#  'statement',
#  'aptn',
#  'news',
#  'stated',
#  'bioarcheologist',
#  'archeological',
#  'works',
#  'underway',
#  'did',
#  'say',
#  'whether',
#  'trained',
#  'handling',
#  'potentially',
#  'criminal',
#  'evidence',
#  'found',
#  'just',
#  'few',
#  'inches',
#  'inside',
#  'plastic',
#  'bag',
#  'tamper',
#  'proof',
#  'stand',
#  'many',
#  'chances',
#  'comes',
#  'chain',
#  'custody',
#  'preserved',
#  'prosecution',
#  'successful',
#  'left',
#  'partially',
#  'covered',
#  'piles',
#  'dirt',
#  'sit',
#  'rain',
#  'since',
#  'july',
#  '25',
#  'where',
#  'sniffer',
#  'dogs',
#  'detected',
#  'scent',
#  'human',
#  'remains',
#  'early',
#  'june',
#  'sifted',
#  'respected',
#  'sift',
#  'extracted',
#  'sniffed',
#  'target',
#  'immediately',
#  'could',
#  'midst',
#  'being',
#  'ignored',
#  'despite',
#  'publicly',
#  'stating',
#  'support',
#  'commitment',
#  'reconciliation',
#  'unilaterally',
#  'deemed',
#  'mandate',
#  'terminated',
#  'would',
#  'mean',
#  'continue',
#  'with',
#  'firm',
#  'ethnoscope',
#  'guided',
#  'rather',
#  'than',
#  'expert',
#  'had',
#  'submit',
#  'two',
#  'submitted',
#  '8',
#  'other',
#  '17',
#  'satisfied',
#  'grateful',
#  'work',
#  'accomplished',
#  'experts',
#  'states',
#  'kanien',
#  'keha',
#  'ka',
#  'agree',
#  'bound',
#  'techniques',
#  'specialists',
#  'carry',
#  'analyse',
#  'relevant',
#  'data',
#  'retain',
#  'discretion',
#  'providers',
#  'appropriate',
#  'qualifications',
#  'expertise',
#  'if',
#  'circumstances',
#  'warrant',
#  'return',
#  'until',
#  'security',
#  'guards',
#  'after',
#  'guard',
#  'private',
#  'company',
#  'hired',
#  'kicked',
#  'off',
#  'grounds',
#  'our',
#  'own',
#  'do',
#  'kahnawake',
#  'ready',
#  'come',
#  're',
#  'working',
#  'bringing',
#  'digs',
#  'suspended',
#  'incident',
#  'dialogue',
#  'd',
#  'hire',
#  'form',
#  'agents',
#  'assigned',
#  'receive',
#  'awareness',
#  'training',
#  'about',
#  'realities',
#  'including',
#  'portion',
#  'residential',
#  'schools',
#  'missing',
#  'well',
#  'specific',
#  'culture',
#  'provided',
#  'kanistensera',
#  'allies',
#  'prepared',
#  'breach',
#  'kehá',
#  'verbally',
#  'assaulted',
#  'personnel',
#  'new',
#  'vic',
#  'project',
#  'week',
#  'later',
#  'issued',
#  'comprehensive',
#  'press',
#  'release',
#  'ongoing',
#  'investigation',
#  'into',
#  'announcing',
#  'anomalies',
#  'during',
#  'archaeological',
#  'however',
#  'soon',
#  'released',
#  'alleging',
#  'failed',
#  'all',
#  'findings',
#  'isolated',
#  'excavation',
#  'alongside',
#  'archaeologists',
#  'stipulated',
#  'royal',
#  'victoria',
#  'hospital',
#  'rvh',
#  'city',
#  'montreal',
#  'attorney',
#  'general',
#  'canada',
#  'cultural',
#  'monitors',
#  'responsible',
#  'ensuring',
#  'completed',
#  'accordance',
#  'protocols',
#  'interview',
#  'tribune',
#  'mother',
#  'kwetiio',
#  'shared',
#  'afternoon',
#  'taking',
#  'virtual',
#  'meeting',
#  'informed',
#  'end',
#  'earlier',
#  'usual',
#  'day',
#  'wrapping',
#  'another',
#  'decided',
#  'walk',
#  'hill',
#  'prompted',
#  'finished',
#  'coming',
#  'down',
#  'towards',
#  'us',
#  'calling',
#  'police',
#  'startled',
#  'went',
#  'member',
#  'team',
#  'alex',
#  'came',
#  'along',
#  'me',
#  'pulled',
#  'phone',
#  'record',
#  'interaction',
#  'got',
#  'top',
#  'whose',
#  'name',
#  'snatched',
#  'his',
#  'hands',
#  'grabbed',
#  'started',
#  'hollering',
#  'at',
#  'm',
#  'filmed',
#  'you',
#  'here',
#  'wait',
#  'minute',
#  'calm',
#  'handed',
#  'stopped',
#  'recording',
#  'deleted',
#  'device',
#  'explained',
#  'became',
#  'increasingly',
#  'hostile',
#  'allowed',
#  'unless',
#  'demanded',
#  'show',
#  'her',
#  'document',
#  've',
#  'pretty',
#  'sure',
#  'give',
#  'pull',
#  'will',
#  'see',
#  'threaten',
#  'call',
#  'numerous',
#  'times',
#  'remarks',
#  'made',
#  'toward',
#  'should',
#  'kids',
#  'take',
#  'care',
#  'ended',
#  'tested',
#  'lie',
#  'happen',
#  'benefit',
#  'yes',
#  'benefits',
#  'kwettio',
#  'respond',
#  'request',
#  'comment',
#  'altercation',
#  'additional',
#  'resolution',
#  'reached',
#  'must',
#  'onsite',
#  'efforts',
#  'halted',
#  '26',
#  'resumed',
#  '23',
#  'discuss',
#  'took',
#  'place',
#  '1',
#  'representative',
#  'office',
#  'independent',
#  'special',
#  'interlocutor',
#  'kimberly',
#  'murray',
#  'pleaded',
#  'defendants',
#  'based',
#  'patrol',
#  'which',
#  'initially',
#  'met',
#  'resistance',
#  'parties',
#  'negotiations',
#  'currently',
#  'continues',
#  'oversee',
#  'while',
#  'representatives',
#  'chosen',
#  'non',
#  'intrusive',
#  'method',
#  'surveying',
#  'mapping',
#  'land',
#  'already',
#  'used',
#  'provost',
#  'vice',
#  'principal',
#  'christopher',
#  'manfredi',
#  'students',
#  'staff',
#  'informing',
#  'performed',
#  'geophysical',
#  'recommended',
#  'likely',
#  'grave',
#  'type',
#  'across',
#  'containing',
#  'anthropologist',
#  'associate',
#  'phillipe',
#  'announcement',
#  'include',
#  'reported',
#  'correct',
#  'adult',
#  'burial',
#  'sites',
#  'several',
#  'others',
#  'different',
#  'sizes',
#  'omitted',
#  'much',
#  'larger',
#  'number',
#  'results',
#  'squarely',
#  'silenced',
#  'denied',
#  'minimized',
#  'asserted',
#  'written',
#  'indicated',
#  'necessarially',
#  'indicative',
#  'angela',
#  'campbell',
#  'reason',
#  'conclusive',
#  'most',
#  'interest',
#  'community',
#  'discoveries',
#  'highly',
#  'unlikely',
#  'definite',
#  'wanted',
#  'communicate',
#  'things',
#  'certain',
#  'what',
#  'so',
#  'begin',
#  'denying',
#  'called',
#  'source',
#  'review',
#  'characterize',
#  'addition',
#  'allowing',
#  'canadian',
#  'association',
#  'caa',
#  'peer',
#  'service',
#  'allow',
#  'argued',
#  'limited',
#  'identifying',
#  'recommending',
#  'such',
#  'never',
#  'agreed',
#  'upon',
#  'interpret',
#  'obtained',
#  'additionally',
#  'provider',
#  'qualified',
#  'firms',
#  'country',
#  'felt',
#  'entrusted',
#  'interpretation',
#  'able',
#  'trust',
#  'collect',
#  'ought',
#  'subject',
#  'second',
#  'confidence',
#  'excavated',
#  'soil',
#  'remained',
#  'above',
#  'worried',
#  'damaged',
#  'weather',
#  'conditions',
#  'bones',
#  'extremely',
#  'improper',
#  'inventory',
#  'more',
#  'ramifications',
#  'forensics',
#  'executive',
#  'director',
#  'pierre',
#  'major',
#  'clarified',
#  'documented',
#  'tarps',
#  'halt',
#  'contain',
#  'direct',
#  'recent',
#  'weeks',
#  'areas',
#  'flagged',
#  'still',
#  'lack',
#  'sufficient',
#  'communication',
#  'cooperation',
#  'every',
#  'little',
#  'grey',
#  'area',
#  'haven',
#  'created',
#  'protocol',
#  'using',
#  'those',
#  'try',
#  'over',
#  'make',
#  'following',
#  'last',
#  'update',
#  'conducted',
#  'former',
#  'priority',
#  'established',
#  'legally',
#  'entered',
#  'april',
#  'known',
#  'redeveloping',
#  'conducting',
#  'summarizing',
#  'its',
#  'n',
#  'total',
#  '9',
#  'signatures',
#  'display',
#  'attributes',
#  'categorize',
#  'outside',
#  'zone',
#  'accounts',
#  '15',
#  'cent',
#  'entire',
#  'follow',
#  'ofexpert',
#  'three',
#  'investigate',
#  'thenine',
#  'manually',
#  'technique',
#  'verify',
#  'theground',
#  'cannot',
#  'confirm',
#  'presenceof',
#  'presence',
#  'ofcultural',
#  'named',
#  'ensureappropriate',
#  'meanwhile',
#  'discussions',
#  'between',
#  'respect',
#  'follows',
#  'reprehensible',
#  'act',
#  'offensive',
#  'directed',
#  'inappropriately',
#  'asked',
#  'leave',
#  'condemned',
#  'action',
#  'dealt',
#  'reach',
#  'among',
#  'measures',
#  'resume',
#  'spirit',
#  'collaboration',
#  'mutual',
#  'adheres',
#  'respects',
#  'keep',
#  'updated',
#  'significant',
#  'events',
#  'occur',
#  'kehà',
#  'kanistansera',
#  'temporary',
#  'injunction',
#  'against',
#  'university',
#  'stop',
#  'renovation',
#  'located',
#  'baby',
#  'closer',
#  'having',
#  'future',
#  'generations',
#  'heard',
#  'past',
#  'whatever',
#  'purpose',
#  'karennatha',
#  'represented',
#  'themselves',
#  'lawyers',
#  'representing',
#  'seen',
#  'hasn',
#  'quite',
#  'frankly',
#  'fact',
#  'justice',
#  'courtroom',
#  'prove',
#  'completely',
#  'shut',
#  'does',
#  'extraordinary',
#  'lawyer',
#  'donald',
#  'worme',
#  'julian',
#  'falconer',
#  'hearing',
#  'legal',
#  'counsel',
#  'r',
#  'associated',
#  'indian',
#  'traditional',
#  'custodians',
#  'presented',
#  'before',
#  'testimony',
#  'mk',
#  'ultra',
#  'psychological',
#  'experiments',
#  'survivor',
#  'lana',
#  'ponting',
#  'witnessed',
#  'clandestine',
#  'digging',
#  'affidavit',
#  'research',
#  'detailing',
#  'historic',
#  'use',
#  'medical',
#  'throughout',
#  '20th',
#  'century',
#  'judge',
#  'hoped',
#  'time',
#  'engage',
#  'discussion',
#  'voices',
#  'pursue',
#  'invasive',
#  'modes',
#  'survey',
#  'destroyed',
#  'weight',
#  'shoulders',
#  'representation',
#  'government',
#  'room',
#  'mind',
#  'boggling',
#  'probably',
#  'striking',
#  'david',
#  'goliath',
#  'stories',
#  'long',
#  'arkéos',
#  'undertake',
#  'bobcat',
#  'ruling',
#  'prior',
#  'likelihood',
#  'low',
#  'karohia',
#  'ron',
#  'dallas',
#  'canady',
#  'binette',
#  'archeology',
#  'student',
#  'kanesatake',
#  'properly',
#  'consent',
#  'big',
#  'issue',
#  'least',
#  'prefer',
#  'methods',
#  'lidar',
#  'aerial',
#  'surveillance',
#  'opposed',
#  'starting',
#  'dig',
#  'might',
#  'home',
#  'pre',
#  'colonial',
#  'iroquois',
#  'village',
#  '2016',
#  'study',
#  'wrote',
#  'op',
#  'ed',
#  'criticizing',
#  'administration',
#  'determine',
#  'construction',
#  'destroy',
#  'artifacts',
#  'consult',
#  'sources',
#  'historical',
#  'documents',
#  'consulted',
#  'geographical',
#  'environment',
#  'kind',
#  'stuff',
#  'constructed',
#  'building',
#  'planning',
#  'perspective',
#  'didn',
#  'knowledge',
#  'keepers',
#  'peoples',
#  'specifically',
#  'kanie',
#  'repeated',
#  'kaniekehaka',
#  'given',
#  'council',
#  'kanawake',
#  'mck',
#  'chief',
#  'ross',
#  'montour',
#  'campus',
#  'falls',
#  'jurisdiction',
#  'therefore',
#  'unable',
#  'either',
#  'approve',
#  'veto',
#  'mountour',
#  'kept',
#  'date',
#  'developments',
#  'mentioned',
#  'first',
#  'nations',
#  'akwesasne',
#  'overseeing',
#  'sparked',
#  'divest',
#  'val',
#  'masny',
#  'president',
#  'external',
#  'rushing',
#  'percent',
#  'chance',
#  'question',
#  'probability',
#  'doing',
#  'rallied',
#  'courthouse',
#  'solidarity',
#  'oct',
#  'everyone',
#  'spoke',
#  'debbie',
#  'delisle',
#  'turtle',
#  'clan',
#  'judges',
#  'elder',
#  'residence',
#  'social',
#  'program',
#  'everybody',
#  'express',
#  'really',
#  'spoken',
#  'invite',
#  'gathering',
#  'concerns',
#  'willing',
#  'open',
#  'arkeos',
#  'available',
#  'deadline',
#  'revisited',
#  'january',
#  ...]
